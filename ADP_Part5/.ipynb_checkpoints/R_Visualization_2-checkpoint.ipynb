# %% [markdown]
# ## 아. 다축(Multiple Axis)
#
# - 모든 과정은 그래프 창을 열어놓은 상태에서 진행되어야 한다

# %% [markdown]
# ### 1) 사용 데이터 입력

# %%
time = seq(7000, 3400, -200)
time
# Out:
#  [1] 7000 6800 6600 6400 6200 6000 5800 5600 5400 5200 5000 4800 4600 4400 4200
# [16] 4000 3800 3600 3400

# %%
pop = c(200,400,450,500,300,100,400,700,830,1200,400,350,200,700,370,800,200,100,120)
pop
# Out:
#  [1]  200  400  450  500  300  100  400  700  830 1200  400  350  200  700  370
# [16]  800  200  100  120

# %%
grp = c(2,5,8,3,2,2,4,7,9,4,4,2,2,7,5,12,5,4,4)
grp
# Out:
#  [1]  2  5  8  3  2  2  4  7  9  4  4  2  2  7  5 12  5  4  4

# %%
med = c(1.2,1.3,1.2,0.9,2.1,1.4,2.9,3.4,2.1,1.1,1.2,1.5,1.2,0.9,0.5,3.3,2.2,1.1,1.2)
med
# Out:
#  [1] 1.2 1.3 1.2 0.9 2.1 1.4 2.9 3.4 2.1 1.1 1.2 1.5 1.2 0.9 0.5 3.3 2.2 1.1 1.2

# %%
# 이거 뭐지 ??
par(mar = c(5,12,4,4) + 0.1)

# %% [markdown]
# ### 2) 다축 생성 절차

# %% [markdown]
# #### step 1 - 첫 번째 그래프 생성

# %%
plot(time, pop, axes = F, xlim = c(7000,3400), ylim = c(0, max(pop)), xlab = '', ylab = '', type = 'l', col = 'black', main = '')
# Out:
# Plot with title ""

# %% [markdown]
# #### step 2 - 첫 번째 그래프에 점 추가

# %%
plot(time, pop, axes = F, xlim = c(7000,3400), ylim = c(0, max(pop)), xlab = '', ylab = '', type = 'l', col = 'black', main = '')
points(time, pop, pch = 20, col = 'black')
# Out:
# Plot with title ""

# %% [markdown]
# #### step 3 - 첫 번째 그래프의 y축 생성

# %%
plot(time, pop, axes = F, xlim = c(7000,3400), ylim = c(0, max(pop)), xlab = '', ylab = '', type = 'l', col = 'black', main = '')
points(time, pop, pch = 20, col = 'black')
# axis(1): x축 # axis(2): y축
axis(2, ylim = c(0, max(pop)), col = 'black', lwd = 2)
# Out:
# Plot with title ""

# %% [markdown]
# #### step 4 - 첫 번째 y축 이름 지정

# %%
plot(time, pop, axes = F, xlim = c(7000,3400), ylim = c(0, max(pop)), xlab = '', ylab = '', type = 'l', col = 'black', main = '')
points(time, pop, pch = 20, col = 'black')
# axis(1): x축 # axis(2): y축
axis(2, ylim = c(0, max(pop)), col = 'black', lwd = 2)
mtext(2, text = 'Population', line = 2)
# Out:
# Plot with title ""

# %% [markdown]
# #### step 5 - 두 번째 그래프 생성

# %%
plot(time, pop, axes = F, xlim = c(7000,3400), ylim = c(0, max(pop)), xlab = '', ylab = '', type = 'l', col = 'black', main = '')
points(time, pop, pch = 20, col = 'black')
# axis(1): x축 # axis(2): y축
axis(2, ylim = c(0, max(pop)), col = 'black', lwd = 2)
mtext(2, text = 'Population', line = 2)

par(new = T)
plot(time, med, axes = F, xlim = c(7000,3400), ylim = c(0, max(med)), xlab = '', ylab = '', type ='l', lty = 2, lwd = 2, col = 'black', main = '')
# Out:
# Plot with title ""

# %% [markdown]
# #### step 6 - 두 번째 그래프에 점 추가

# %%
plot(time, pop, axes = F, xlim = c(7000,3400), ylim = c(0, max(pop)), xlab = '', ylab = '', type = 'l', col = 'black', main = '')
points(time, pop, pch = 20, col = 'black')
# axis(1): x축 # axis(2): y축
axis(2, ylim = c(0, max(pop)), col = 'black', lwd = 2)
mtext(2, text = 'Population', line = 2)

par(new = T)
plot(time, med, axes = F, xlim = c(7000,3400), ylim = c(0, max(med)), xlab = '', ylab = '', type ='l', lty = 2, lwd = 2, col = 'black', main = '')
points(time, med, pch = 20, col = 'black')
# Out:
# Plot with title ""

# %% [markdown]
# #### step 7 - 두 번째 그래프의 y축 생성

# %%
plot(time, pop, axes = F, xlim = c(7000,3400), ylim = c(0, max(pop)), xlab = '', ylab = '', type = 'l', col = 'black', main = '')
points(time, pop, pch = 20, col = 'black')
# axis(1): x축 # axis(2): y축
axis(2, ylim = c(0, max(pop)), col = 'black', lwd = 2)
mtext(2, text = 'Population', line = 2)

par(new = T)
plot(time, med, axes = F, xlim = c(7000,3400), ylim = c(0, max(med)), xlab = '', ylab = '', type ='l', lty = 2, lwd = 2, col = 'black', main = '')
points(time, med, pch = 20, col = 'black')
axis(2, ylim = c(0,max(med)), col = 'black', lwd = 2, line = 3.5)
# Out:
# Plot with title ""

# %% [markdown]
# #### step 8 - 두 번째 y축 이름 지정

# %%
plot(time, pop, axes = F, xlim = c(7000,3400), ylim = c(0, max(pop)), xlab = '', ylab = '', type = 'l', col = 'black', main = '')
points(time, pop, pch = 20, col = 'black')
# axis(1): x축 # axis(2): y축
axis(2, ylim = c(0, max(pop)), col = 'black', lwd = 2)
mtext(2, text = 'Population', line = 2)

par(new = T)
plot(time, med, axes = F, xlim = c(7000,3400), ylim = c(0, max(med)), xlab = '', ylab = '', type ='l', lty = 2, lwd = 2, col = 'black', main = '')
points(time, med, pch = 20, col = 'black')
axis(2, ylim = c(0,max(med)), col = 'black', lwd = 2, line = 3.5 )
mtext(2, text = 'Median Group size', line = 5.5)
# Out:
# Plot with title ""

# %% [markdown]
# #### step 9 - 세 번째 그래프 생성

# %%
plot(time, pop, axes = F, xlim = c(7000,3400), ylim = c(0, max(pop)), xlab = '', ylab = '', type = 'l', col = 'black', main = '')
points(time, pop, pch = 20, col = 'black')
# axis(1): x축 # axis(2): y축
axis(2, ylim = c(0, max(pop)), col = 'black', lwd = 2)
mtext(2, text = 'Population', line = 2)

par(new = T)
plot(time, med, axes = F, xlim = c(7000,3400), ylim = c(0, max(med)), xlab = '', ylab = '', type ='l', lty = 2, lwd = 2, col = 'black', main = '')
points(time, med, pch = 20, col = 'black')
axis(2, ylim = c(0,max(med)), col = 'black', lwd = 2, line = 3.5 )
mtext(2, text = 'Median Group size', line = 5.5)

par(new = T)
plot(time, grp, axes = F, xlim = c(7000,3400), ylim = c(0, max(grp)), xlab = '', ylab = '', type ='l', lty = 3, lwd = 2, col = 'black', main = '')
# Out:
# Plot with title ""

# %% [markdown]
# #### step 10 - 세 번째 그래프의 y축 생성

# %%
plot(time, pop, axes = F, xlim = c(7000,3400), ylim = c(0, max(pop)), xlab = '', ylab = '', type = 'l', col = 'black', main = '')
points(time, pop, pch = 20, col = 'black')
# axis(1): x축 # axis(2): y축
axis(2, ylim = c(0, max(pop)), col = 'black', lwd = 2)
mtext(2, text = 'Population', line = 2)

par(new = T)
plot(time, med, axes = F, xlim = c(7000,3400), ylim = c(0, max(med)), xlab = '', ylab = '', type ='l', lty = 2, lwd = 2, col = 'black', main = '')
points(time, med, pch = 20, col = 'black')
axis(2, ylim = c(0,max(med)), col = 'black', lwd = 2, line = 3.5 )
mtext(2, text = 'Median Group size', line = 5.5)

par(new = T)
plot(time, grp, axes = F, xlim = c(7000,3400), ylim = c(0, max(grp)), xlab = '', ylab = '', type ='l', lty = 3, lwd = 2, col = 'black', main = '')
axis(2, ylim = c(0, max(grp)), col = 'black', lwd = 2, line = 7)
# Out:
# Plot with title ""

# %% [markdown]
# #### step 11 - 세 번째 그래프에 점 추가

# %%
plot(time, pop, axes = F, xlim = c(7000,3400), ylim = c(0, max(pop)), xlab = '', ylab = '', type = 'l', col = 'black', main = '')
points(time, pop, pch = 20, col = 'black')
# axis(1): x축 # axis(2): y축
axis(2, ylim = c(0, max(pop)), col = 'black', lwd = 2)
mtext(2, text = 'Population', line = 2)

par(new = T)
plot(time, med, axes = F, xlim = c(7000,3400), ylim = c(0, max(med)), xlab = '', ylab = '', type ='l', lty = 2, lwd = 2, col = 'black', main = '')
points(time, med, pch = 20, col = 'black')
axis(2, ylim = c(0,max(med)), col = 'black', lwd = 2, line = 3.5 )
mtext(2, text = 'Median Group size', line = 5.5)

par(new = T)
plot(time, grp, axes = F, xlim = c(7000,3400), ylim = c(0, max(grp)), xlab = '', ylab = '', type ='l', lty = 3, lwd = 2, col = 'black', main = '')
axis(2, ylim = c(0, max(grp)), col = 'black', lwd = 2, line = 7)
points(time, grp, pch = 20, col = 'black')
# Out:
# Plot with title ""

# %% [markdown]
# #### step 12 - 세 번째 y축 이름 지정

# %%
plot(time, pop, axes = F, xlim = c(7000,3400), ylim = c(0, max(pop)), xlab = '', ylab = '', type = 'l', col = 'black', main = '')
points(time, pop, pch = 20, col = 'black')
# axis(1): x축 # axis(2): y축
axis(2, ylim = c(0, max(pop)), col = 'black', lwd = 2)
mtext(2, text = 'Population', line = 2)

par(new = T)
plot(time, med, axes = F, xlim = c(7000,3400), ylim = c(0, max(med)), xlab = '', ylab = '', type ='l', lty = 2, lwd = 2, col = 'black', main = '')
points(time, med, pch = 20, col = 'black')
axis(2, ylim = c(0,max(med)), col = 'black', lwd = 2, line = 3.5 )
mtext(2, text = 'Median Group size', line = 5.5)

par(new = T)
plot(time, grp, axes = F, xlim = c(7000,3400), ylim = c(0, max(grp)), xlab = '', ylab = '', type ='l', lty = 3, lwd = 2, col = 'black', main = '')
axis(2, ylim = c(0, max(grp)), col = 'black', lwd = 2, line = 7)
points(time, grp, pch = 20, col = 'black')
mtext(2, text = 'Number of Groups', line = 9)
# Out:
# Plot with title ""

# %% [markdown]
# #### step 13 - x축 생성 및 이름 지정

# %%
plot(time, pop, axes = F, xlim = c(7000,3400), ylim = c(0, max(pop)), xlab = '', ylab = '', type = 'l', col = 'black', main = '')
points(time, pop, pch = 20, col = 'black')
# axis(1): x축 # axis(2): y축
axis(2, ylim = c(0, max(pop)), col = 'black', lwd = 2)
mtext(2, text = 'Population', line = 2)

par(new = T)
plot(time, med, axes = F, xlim = c(7000,3400), ylim = c(0, max(med)), xlab = '', ylab = '', type ='l', lty = 2, lwd = 2, col = 'black', main = '')
points(time, med, pch = 20, col = 'black')
axis(2, ylim = c(0,max(med)), col = 'black', lwd = 2, line = 3.5 )
mtext(2, text = 'Median Group size', line = 5.5)

par(new = T)
plot(time, grp, axes = F, xlim = c(7000,3400), ylim = c(0, max(grp)), xlab = '', ylab = '', type ='l', lty = 3, lwd = 2, col = 'black', main = '')
axis(2, ylim = c(0, max(grp)), col = 'black', lwd = 2, line = 7)
points(time, grp, pch = 20, col = 'black')
mtext(2, text = 'Number of Groups', line = 9)
axis(1, pretty(range(time), 10))
# Out:
# Plot with title ""

# %% [markdown]
# #### step 14 - 사용자화 : 라인별로 설명을 붙이는 등 좀 더 이해하기 쉽도록 조정

# %%
plot(time, pop, axes = F, xlim = c(7000,3400), ylim = c(0, max(pop)), xlab = '', ylab = '', type = 'l', col = 'black', main = '')
points(time, pop, pch = 20, col = 'black')
# axis(1): x축 # axis(2): y축
axis(2, ylim = c(0, max(pop)), col = 'black', lwd = 2)
mtext(2, text = 'Population', line = 2)

par(new = T)
plot(time, med, axes = F, xlim = c(7000,3400), ylim = c(0, max(med)), xlab = '', ylab = '', type ='l', lty = 2, lwd = 2, col = 'black', main = '')
points(time, med, pch = 20, col = 'black')
axis(2, ylim = c(0,max(med)), col = 'black', lwd = 2, line = 3.5 )
mtext(2, text = 'Median Group size', line = 5.5)

par(new = T)
plot(time, grp, axes = F, xlim = c(7000,3400), ylim = c(0, max(grp)), xlab = '', ylab = '', type ='l', lty = 3, lwd = 2, col = 'black', main = '')
axis(2, ylim = c(0, max(grp)), col = 'black', lwd = 2, line = 7)
points(time, grp, pch = 20, col = 'black')
mtext(2, text = 'Number of Groups', line = 9)
axis(1, pretty(range(time), 10))
legend(x = 7000, y = 12, legend = c('Population', 'Median Group size', 'Number of Groups'), lty = c(1,2,3))
# Out:
# Plot with title ""

# %% [markdown]
# ## 자. 그 외 다양한 그래프

# %% [markdown]
# ### 1) aplpack 패키지 설치
#
# - aplpack 패키지 : 줄기-잎 그림, 체르노프 페이스, 스타차트 등 시각화 방법을 제공
# - aplpack 패키지의 설치 방법은 아래와 같다

# %%
install.packages('aplpack')
library(aplpack)
# Out:
# Installing package into 'C:/Users/bcduc/Documents/R/win-library/3.6'
# (as 'lib' is unspecified)
# package 'aplpack' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\bcduc\AppData\Local\Temp\RtmpWwJjUP\downloaded_packages

# %% [markdown]
# ### 2) 줄기-잎 그림
# - 22명의 1학기 중간고사 수학 성적 데이터에 대한 줄기-잎 그림은 아래와 같다

# %%
score = c(1,2,3,4,10,2,30,42,31,50,80,76,90,87,21,43,65,76,32,12,34,54)
score
# Out:
#  [1]  1  2  3  4 10  2 30 42 31 50 80 76 90 87 21 43 65 76 32 12 34 54

# %%
# 어떻게 보는건지 잘 모르겠다.
stem.leaf(score)
# Out:
# 1 | 2: represents 12
#  leaf unit: 1
#             n: 22
#    5    0 | 12234
#    7    1 | 02
#    8    2 | 1
#   (4)   3 | 0124
#   10    4 | 23
#    8    5 | 04
#    6    6 | 5
#    5    7 | 66
#    3    8 | 07
#    1    9 | 0

# %% [markdown]
# ### 3) 얼굴 그림
# - WorldPhones 데이터를 이용
# - 국가별, 연도별 전화기 숫자

# %%
WorldPhones
# Out:
#      N.Amer Europe Asia S.Amer Oceania Africa Mid.Amer
# 1951 45939  21574  2876 1815   1646      89    555
# 1956 60423  29990  4708 2568   2366    1411    733
# 1957 64721  32510  5230 2695   2526    1546    773
# 1958 68484  35218  6662 2845   2691    1663    836
# 1959 71799  37598  6856 3000   2868    1769    911
# 1960 76036  40341  8220 3145   3054    1905   1008
# 1961 79831  43173  9053 3338   3224    2005   1076

# %%
faces(WorldPhones)
# Out:
# effect of variables:
#  modified item       Var
#  "height of face   " "N.Amer"
#  "width of face    " "Europe"
#  "structure of face" "Asia"
#  "height of mouth  " "S.Amer"
#  "width of mouth   " "Oceania"
#  "smiling          " "Africa"
#  "height of eyes   " "Mid.Amer"
#  "width of eyes    " "N.Amer"
#  "height of hair   " "Europe"
#  "width of hair   "  "Asia"
#  "style of hair   "  "S.Amer"
#  "height of nose  "  "Oceania"
#  "width of nose   "  "Africa"
#  "width of ear    "  "Mid.Amer"
#  "height of ear   "  "N.Amer"
# Plot with title "1961"

# %% [markdown]
# ### 4) 별 그림

# %%
# 어떻게 보는건지 모르겠는데 ?
stars(WorldPhones)
# Out:
# plot without title
